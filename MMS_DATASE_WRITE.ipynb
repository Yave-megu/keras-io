# %% [markdown]
# <a href="https://colab.research.google.com/github/Yave-megu/keras-io/blob/master/MMS_DATASE_WRITE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Libarary Porting
import os, re, glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# %%
IMG_DIR = "/content/drive/My Drive/Colab Notebooks/MMSclassification/"
categories=["Mild","Moderate","Severe"]
nb_classes = len(categories)

# %%
image_w =32
image_h = 32

X=[]
Y=[]

# %%
for idx,cate in enumerate(categories):
  label = [0 for i in range(nb_classes)]
  label[idx]=1
  image_dir = IMG_DIR+cate+"/"

  for top,dir,f in os.walk(image_dir):
    for filename in f:
      print(image_dir + filename)
      img = cv2.imread(image_dir + filename)
      img = cv2.resize(img, None, fx=image_w/img.shape[1], fy = image_h/img.shape[0])
      X.append(img/256)
      Y.append(label)



X= np.array(X)
Y= np.array(Y)

X_train,X_test,Y_train,Ytest = train_test_split(X,Y)
xy = (X_train,X_test,Y_train,Ytest)

np.save("/content/drive/My Drive/Colab Notebooks/MMSclassification/.img_data.npy",xy)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/06625825_cat2_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/06625825_cat_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/09713930_cat2_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/09713930_cat_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/09713930_cat3_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/09713930_cat4_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/11457295_cat_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/11457295_cat2_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/04906580_cat1_GD3.JPG
# /content/drive/My Drive/Colab Notebooks/MMSclassification/Moderate/04906580_cat2_GD3.JPG
# ...

# %% [markdown]
# Todo: 진행상황 보고 메세지 추가
